# %%
import pandas as pd

res = pd.read_csv('/Users/chkapsalis/Desktop/nlp_project/working/annot_schema/results.csv', header=0, sep=',', index_col=False)
res.head()
# Out:
#                 label                                 word_1  \
# 0  MEDICAL-CONDITIONS  "Acute respiratory distress syndrome"
# 1            SYMPTOMS                             "1. Fever"
# 2          TREATMENTS                              "Vaccine"
# 3              EVENTS           "1. Global pandemic declared
# 4            POLICIES                         "mask mandate"
#
#                                word_2                    word_3  \
# 0                         "Pneumonia"                  "Sepsis"
# 1                          "2. Cough"  "3. Shortness of breath"
# 2                        "Remdesivir"           "Dexamethasone"
# 3  2. Travel restrictions implemented         3. Schools closed
# 4      "social distancing guidelines"     "stay-at-home orders"
#
#                             word_4                            word_5  \
# 0                           "ARDS"                  "Cytokine storm"
# 1                     "4. Fatigue"                   "5. Body aches"
# 2    "Convalescent plasma therapy"           "Monoclonal antibodies"
# 3  4. Work from home orders issued         5. Mask mandates enforced
# 4        "quarantine requirements"  "capacity limits for businesses"
#
#                                        word_6  \
# 0                       "Multi-organ failure"
# 1                 "6. Loss of taste or smell"
# 2                               "Tocilizumab"
# 3  6. Social distancing guidelines introduced
# 4                       "travel restrictions"
#
#                                 word_7                           word_8  \
# 0                          "Hypoxemia"                   "Coagulopathy"
# 1                     "7. Sore throat"    "8. Congestion or runny nose"
# 2                         "Ivermectin"                    "Favipiravir"
# 3  7. Vaccination campaigns rolled out  8. Economic shutdowns initiated
# 4    "mandatory testing for travelers"           "remote work policies"
#
#                                      word_9  \
# 0                     "Acute kidney injury"
# 1                   "9. Nausea or vomiting"
# 2                            "Azithromycin"
# 3  9. Testing and contact tracing ramped up
# 4                         "school closures"
#
#                                word_10
# 0       "Cardiovascular complications"
# 1                       "10. Diarrhea"
# 2                        "Baricitinib"
# 3  10. Healthcare systems overwhelmed"
# 4                "mass gathering bans"

# %%
for col in res.columns.difference(['label']):
    res[col] = res[col].str.replace('"',"")
    res[col] = res[col].str.replace(r'\d\.?', '', regex=True)
    res[col] = res[col].str.lower()
    res[col] = res[col].str.strip()

# %%
res.head()
# Out:
#                 label                               word_1  \
# 0  MEDICAL-CONDITIONS  acute respiratory distress syndrome
# 1            SYMPTOMS                                fever
# 2          TREATMENTS                              vaccine
# 3              EVENTS             global pandemic declared
# 4            POLICIES                         mask mandate
#
#                             word_2               word_3  \
# 0                        pneumonia               sepsis
# 1                            cough  shortness of breath
# 2                       remdesivir        dexamethasone
# 3  travel restrictions implemented       schools closed
# 4     social distancing guidelines  stay-at-home orders
#
#                          word_4                          word_5  \
# 0                          ards                  cytokine storm
# 1                       fatigue                      body aches
# 2   convalescent plasma therapy           monoclonal antibodies
# 3  work from home orders issued          mask mandates enforced
# 4       quarantine requirements  capacity limits for businesses
#
#                                     word_6                            word_7  \
# 0                      multi-organ failure                         hypoxemia
# 1                   loss of taste or smell                       sore throat
# 2                              tocilizumab                        ivermectin
# 3  social distancing guidelines introduced  vaccination campaigns rolled out
# 4                      travel restrictions   mandatory testing for travelers
#
#                          word_8                                 word_9  \
# 0                  coagulopathy                    acute kidney injury
# 1      congestion or runny nose                     nausea or vomiting
# 2                   favipiravir                           azithromycin
# 3  economic shutdowns initiated  testing and contact tracing ramped up
# 4          remote work policies                        school closures
#
#                           word_10
# 0    cardiovascular complications
# 1                        diarrhea
# 2                     baricitinib
# 3  healthcare systems overwhelmed
# 4             mass gathering bans

# %%
res.to_csv('results2.csv', index=False, sep=',')

# %%
# function necessary to get the `wordnet` representation of the part-of-speech tag so
# I can use it in other wordnet operations
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
# I see some of these phrases are longer but the words they contain it is safe to assume that -given the fact that our training tweets are all covid-related
# will always pertain to pandemic-themed discussions/statements
from itertools import chain
import nltk
from nltk import ne_chunk, pos_tag, word_tokenize, sent_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

stop_words = stopwords.words('english')
from nltk.corpus import wordnet

# Dictionary that will map labels of the annotation schema to sets containing all synonyms of the GPT-generated anchor words for each of them
# I also make sure the original phrases/words are included
syn_sets = dict()
syn_sets.update({label: set() for label in res['label'].unique()})  # the `update` method overwrites the -nonexisting so doesn't matter- initial values

# So for each label, I will go through them one by one and -ignoring stopwords- I will find synonyms from wordnet to extend our vocabulary
for label in res['label'].unique():
    phrases = [res[res['label'] == label][i].values[0] for i in res.columns.difference(['label'])]
    for phrase in phrases:
        tokens = word_tokenize(phrase)
        print(tokens)
        pos = pos_tag(tokens)
        print(pos)
        for token in tokens:
            synonyms = wordnet.synsets(token, pos=get_wordnet_pos(pos[0][1]), lang='eng')
            lemmas = set([i.lower().replace('_',' ') for i in chain.from_iterable([word.lemma_names() for word in synonyms]) if i.lower() not in stop_words])  # flatten the list of lists into a continuous list in place, plus
            lemmas.add(phrase)
            # getting rid of duplicate values
            # [word.lemma_names() for word in synonyms]  # this would return a nuanced list of lists with possible duplicate values across lists
            if lemmas:
                syn_sets[label].update(lemmas)
                print(lemmas)
# Out:
# ['acute', 'respiratory', 'distress', 'syndrome']
# [('acute', 'JJ'), ('respiratory', 'NN'), ('distress', 'NN'), ('syndrome', 'NN')]
# {'acuate', 'incisive', 'intense', 'acute respiratory distress syndrome', 'sharp', 'knifelike', 'keen', 'needlelike', 'discriminating', 'penetrating', 'penetrative', 'acute', 'piercing'}
# {'acute respiratory distress syndrome', 'respiratory'}
# {'acute respiratory distress syndrome'}
# {'acute respiratory distress syndrome'}
# ['cardiovascular', 'complications']
# [('cardiovascular', 'JJ'), ('complications', 'NNS')]
# {'cardiovascular', 'cardiovascular complications'}
# {'cardiovascular complications'}
# ['pneumonia']
# [('pneumonia', 'NN')]
# {'pneumonia'}
# ['sepsis']
# [('sepsis', 'NN')]
# {'sepsis'}
# ['ards']
# [('ards', 'NNS')]
# {'ards', 'wet lung', 'adult respiratory distress syndrome', 'white lung'}
# ['cytokine', 'storm']
# [('cytokine', 'NN'), ('storm', 'NN')]
# {'cytokine', 'cytokine storm'}
# {'storm', 'violent storm', 'tempest', 'cytokine storm'}
# ['multi-organ', 'failure']
# [('multi-organ', 'JJ'), ('failure', 'NN')]
# {'multi-organ failure'}
# {'multi-organ failure'}
# ['hypoxemia']
# [('hypoxemia', 'NN')]
# {'hypoxemia'}
# ['coagulopathy']
# [('coagulopathy', 'NN')]
# {'coagulopathy'}
# ['acute', 'kidney', 'injury']
# [('acute', 'JJ'), ('kidney', 'NN'), ('injury', 'NN')]
# {'acuate', 'incisive', 'intense', 'sharp', 'knifelike', 'keen', 'needlelike', 'discriminating', 'penetrating', 'penetrative', 'acute kidney injury', 'acute', 'piercing'}
# {'acute kidney injury'}
# {'acute kidney injury'}
# ['fever']
# [('fever', 'NN')]
# {'febricity', 'fever', 'pyrexia', 'febrility', 'feverishness'}
# ['diarrhea']
# [('diarrhea', 'NN')]
# {'diarrhoea', 'looseness of the bowels', 'diarrhea', 'looseness'}
# ['cough']
# [('cough', 'NN')]
# {'coughing', 'cough'}
# ['shortness', 'of', 'breath']
# [('shortness', 'NN'), ('of', 'IN'), ('breath', 'NN')]
# {'curtness', 'abruptness', 'shortness of breath', 'truncation', 'brusqueness', 'shortness', 'gruffness'}
# {'shortness of breath'}
# {'breathing spell', 'breath', 'intimation', 'breathing time', 'breathing space', 'shortness of breath', 'breathing place', 'breather', 'hint'}
# ['fatigue']
# [('fatigue', 'NN')]
# {'tiredness', 'fatigue', 'weariness', 'fatigue duty'}
# ['body', 'aches']
# [('body', 'NN'), ('aches', 'NNS')]
# {'organic structure', 'torso', 'consistency', 'consistence', 'eubstance', 'soundbox', 'physical structure', 'dead body', 'body aches', 'body', 'trunk'}
# {'body aches', 'ache', 'aching'}
# ['loss', 'of', 'taste', 'or', 'smell']
# [('loss', 'NN'), ('of', 'IN'), ('taste', 'NN'), ('or', 'CC'), ('smell', 'NN')]
# {'red', 'expiration', 'exit', 'loss', 'release', 'going', 'deprivation', 'red ink', 'personnel casualty', 'passing', 'departure', 'loss of taste or smell'}
# {'loss of taste or smell'}
# {'taste', 'taste sensation', 'discernment', 'mouthful', 'gustatory sensation', 'perceptiveness', 'sense of taste', 'loss of taste or smell', 'predilection', 'appreciation', 'tasting', 'taste perception', 'penchant', 'gustatory perception', 'gustation', 'gustatory modality', 'preference'}
# {'operating theatre', 'operating theater', 'oregon', 'operating room', 'surgery', 'loss of taste or smell', 'beaver state'}
# {'olfaction', 'odor', 'olfactory sensation', 'olfactory perception', 'olfactory property', 'flavour', 'look', 'smell', 'feel', 'smelling', 'feeling', 'odour', 'loss of taste or smell', 'tone', 'scent', 'spirit', 'olfactory modality', 'sense of smell', 'aroma', 'flavor'}
# ['sore', 'throat']
# [('sore', 'NN'), ('throat', 'NN')]
# {'sore', 'sore throat'}
# {'sore throat', 'pharynx', 'throat'}
# ['congestion', 'or', 'runny', 'nose']
# [('congestion', 'NN'), ('or', 'CC'), ('runny', 'NN'), ('nose', 'NN')]
# {'congestion', 'congestion or runny nose', 'over-crowding'}
# {'operating theatre', 'operating theater', 'oregon', 'operating room', 'surgery', 'congestion or runny nose', 'beaver state'}
# {'congestion or runny nose'}
# {'olfactory organ', 'nozzle', 'nose', 'congestion or runny nose'}
# ['nausea', 'or', 'vomiting']
# [('nausea', 'NN'), ('or', 'CC'), ('vomiting', 'NN')]
# {'sickness', 'nausea', 'nausea or vomiting'}
# {'operating theatre', 'nausea or vomiting', 'operating theater', 'oregon', 'operating room', 'surgery', 'beaver state'}
# {'nausea or vomiting', 'emesis', 'vomiting', 'vomit', 'regurgitation', 'puking', 'disgorgement'}
# ['vaccine']
# [('vaccine', 'NN')]
# {'vaccine', 'vaccinum'}
# ['baricitinib']
# [('baricitinib', 'NN')]
# {'baricitinib'}
# ['remdesivir']
# [('remdesivir', 'NN')]
# {'remdesivir'}
# ['dexamethasone']
# [('dexamethasone', 'NN')]
# {'dexamethasone', 'hexadrol', 'dexone', 'dexamethasone intensol', 'oradexon', 'decadron'}
# ['convalescent', 'plasma', 'therapy']
# [('convalescent', 'NN'), ('plasma', 'NN'), ('therapy', 'NN')]
# {'convalescent plasma therapy', 'convalescent'}
# {'plasm', 'convalescent plasma therapy', 'blood plasma', 'plasma'}
# {'therapy', 'convalescent plasma therapy'}
# ['monoclonal', 'antibodies']
# [('monoclonal', 'JJ'), ('antibodies', 'NNS')]
# {'monoclonal', 'monoclonal antibodies'}
# {'monoclonal antibodies'}
# ['tocilizumab']
# [('tocilizumab', 'NN')]
# {'tocilizumab'}
# ['ivermectin']
# [('ivermectin', 'NN')]
# {'ivermectin'}
# ['favipiravir']
# [('favipiravir', 'NN')]
# {'favipiravir'}
# ['azithromycin']
# [('azithromycin', 'NN')]
# {'azithromycin', 'zithromax'}
# ['global', 'pandemic', 'declared']
# [('global', 'JJ'), ('pandemic', 'NN'), ('declared', 'VBD')]
# {'planetary', 'worldwide', 'world', 'spherical', 'global pandemic declared', 'spheric', 'globular', 'global', 'world-wide', 'globose', 'orbicular', 'ball-shaped'}
# {'pandemic', 'global pandemic declared'}
# {'stated', 'global pandemic declared', 'declared'}
# ['healthcare', 'systems', 'overwhelmed']
# [('healthcare', 'NN'), ('systems', 'NNS'), ('overwhelmed', 'VBD')]
# {'healthcare systems overwhelmed', 'healthcare', 'health care'}
# {'organization', 'system of rules', 'system', 'scheme', 'healthcare systems overwhelmed', 'organisation', 'arrangement'}
# {'healthcare systems overwhelmed'}
# ['travel', 'restrictions', 'implemented']
# [('travel', 'NN'), ('restrictions', 'NNS'), ('implemented', 'VBD')]
# {'travel', 'locomotion', 'change of location', 'travelling', 'travel restrictions implemented', 'traveling'}
# {'restriction', 'confinement', 'limitation', 'travel restrictions implemented'}
# {'travel restrictions implemented'}
# ['schools', 'closed']
# [('schools', 'NNS'), ('closed', 'VBD')]
# {'schooltime', 'school', 'shoal', 'school day', 'schoolhouse', 'schools closed', 'schooling'}
# {'schools closed'}
# ['work', 'from', 'home', 'orders', 'issued']
# [('work', 'NN'), ('from', 'IN'), ('home', 'NN'), ('orders', 'NNS'), ('issued', 'VBD')]
# {'body of work', 'work', 'study', 'work from home orders issued', 'employment', 'oeuvre', 'piece of work', 'workplace'}
# {'work from home orders issued'}
# {'home', 'plate', 'dwelling house', 'dwelling', 'home base', 'base', 'house', 'work from home orders issued', 'family', 'place', 'menage', 'abode', 'habitation', 'rest home', 'nursing home', 'household', 'home plate', 'domicile'}
# {'ordering', 'rules of order', 'work from home orders issued', 'ordination', 'purchase order', 'club', 'social club', 'holy order', 'guild', 'parliamentary law', 'order', 'decree', 'parliamentary procedure', 'edict', 'fiat', 'lodge', 'gild', 'orderliness', 'monastic order', 'order of magnitude', 'society', 'rescript'}
# {'work from home orders issued'}
# ['mask', 'mandates', 'enforced']
# [('mask', 'NN'), ('mandates', 'NNS'), ('enforced', 'VBD')]
# {'masquerade party', 'masquerade', 'mask mandates enforced', 'masque', 'mask'}
# {'mandatory', 'authorization', 'authorisation', 'mask mandates enforced', 'mandate'}
# {'mask mandates enforced'}
# ['social', 'distancing', 'guidelines', 'introduced']
# [('social', 'JJ'), ('distancing', 'NN'), ('guidelines', 'NNS'), ('introduced', 'VBD')]
# {'social', 'social distancing guidelines introduced', 'societal'}
# {'social distancing guidelines introduced'}
# {'social distancing guidelines introduced'}
# {'social distancing guidelines introduced'}
# ['vaccination', 'campaigns', 'rolled', 'out']
# [('vaccination', 'NN'), ('campaigns', 'NNS'), ('rolled', 'VBD'), ('out', 'RP')]
# {'vaccination', 'inoculation', 'vaccination campaigns rolled out'}
# {'drive', 'campaign', 'military campaign', 'vaccination campaigns rolled out', 'run', 'crusade', 'cause', 'movement', 'hunting expedition', 'safari', 'effort', 'political campaign'}
# {'vaccination campaigns rolled out'}
# {'vaccination campaigns rolled out'}
# ['economic', 'shutdowns', 'initiated']
# [('economic', 'JJ'), ('shutdowns', 'NNS'), ('initiated', 'VBD')]
# {'economical', 'economic shutdowns initiated', 'economic'}
# {'economic shutdowns initiated'}
# {'economic shutdowns initiated'}
# ['testing', 'and', 'contact', 'tracing', 'ramped', 'up']
# [('testing', 'VBG'), ('and', 'CC'), ('contact', 'JJ'), ('tracing', 'NN'), ('ramped', 'VBD'), ('up', 'RP')]
# {'try out', 'testing and contact tracing ramped up', 'quiz', 'screen', 'try', 'essay', 'examine', 'test', 'prove'}
# {'testing and contact tracing ramped up'}
# {'testing and contact tracing ramped up', 'get hold of', 'adjoin', 'touch', 'get through', 'meet', 'contact', 'reach'}
# {'draw', 'testing and contact tracing ramped up', 'hunt', 'retrace', 'line', 'delineate', 'hound', 'follow', 'decipher', 'describe', 'trace'}
# {'storm', 'rage', 'ramp', 'testing and contact tracing ramped up'}
# {'testing and contact tracing ramped up'}
# ['mask', 'mandate']
# [('mask', 'NN'), ('mandate', 'NN')]
# {'mask mandate', 'masquerade party', 'masquerade', 'masque', 'mask'}
# {'mandatory', 'authorization', 'authorisation', 'mask mandate', 'mandate'}
# ['mass', 'gathering', 'bans']
# [('mass', 'NN'), ('gathering', 'NN'), ('bans', 'NNS')]
# {'people', 'mickle', 'stack', 'bulk', 'good deal', 'raft', 'wad', 'peck', 'spate', 'mass', 'hatful', 'quite a little', 'volume', 'great deal', 'heap', 'batch', 'pot', 'masses', 'mass gathering bans', 'mess', 'pile', 'lot', 'flock', 'mountain', 'deal', 'sight', 'passel', 'the great unwashed', 'hoi polloi', 'muckle', 'multitude', 'slew', 'plenty', 'mint', 'tidy sum'}
# {'gathering', 'gather', 'mass gathering bans', 'assemblage', 'assembly'}
# {'forbiddance', 'ban', 'prohibition', 'forbidding', 'mass gathering bans', 'proscription', 'bachelor of arts in nursing', 'banning'}
# ['social', 'distancing', 'guidelines']
# [('social', 'JJ'), ('distancing', 'NN'), ('guidelines', 'NNS')]
# {'social', 'social distancing guidelines', 'societal'}
# {'social distancing guidelines'}
# {'social distancing guidelines'}
# ['stay-at-home', 'orders']
# [('stay-at-home', 'JJ'), ('orders', 'NNS')]
# {'stay-at-home orders', 'stay-at-home'}
# {'stay-at-home orders'}
# ['quarantine', 'requirements']
# [('quarantine', 'NN'), ('requirements', 'NNS')]
# {'quarantine requirements', 'quarantine'}
# {'demand', 'requisite', 'essential', 'necessity', 'prerequisite', 'requirement', 'necessary', 'quarantine requirements'}
# ['capacity', 'limits', 'for', 'businesses']
# [('capacity', 'NN'), ('limits', 'NNS'), ('for', 'IN'), ('businesses', 'NNS')]
# {'capacity', 'capacity limits for businesses', 'content', 'electrical capacity', 'capability', 'capacitance', 'mental ability'}
# {'point of accumulation', 'bound', 'boundary', 'limit point', 'limitation', 'capacity limits for businesses', 'demarcation', 'demarcation line', 'terminal point', 'terminus ad quem', 'limit'}
# {'capacity limits for businesses'}
# {'business organisation', 'concern', 'byplay', 'job', 'commercial enterprise', 'line of work', 'line', 'business sector', 'patronage', 'business concern', 'capacity limits for businesses', 'business', 'business enterprise', 'business organization', 'stage business', 'clientele', 'occupation'}
# ['travel', 'restrictions']
# [('travel', 'NN'), ('restrictions', 'NNS')]
# {'travel', 'locomotion', 'change of location', 'travel restrictions', 'travelling', 'traveling'}
# {'restriction', 'travel restrictions', 'confinement', 'limitation'}
# ['mandatory', 'testing', 'for', 'travelers']
# [('mandatory', 'JJ'), ('testing', 'VBG'), ('for', 'IN'), ('travelers', 'NNS')]
# {'mandatory', 'required', 'compulsory', 'mandatory testing for travelers'}
# {'mandatory testing for travelers'}
# {'mandatory testing for travelers'}
# {'mandatory testing for travelers'}
# ['remote', 'work', 'policies']
# [('remote', 'JJ'), ('work', 'NN'), ('policies', 'NNS')]
# {'remote', 'outside', 'outback', 'removed', 'distant', 'remote work policies'}
# {'remote work policies'}
# {'remote work policies'}
# ['school', 'closures']
# [('school', 'NN'), ('closures', 'NNS')]
# {'school closures', 'schooltime', 'school', 'shoal', 'school day', 'schoolhouse', 'schooling'}
# {'school closures', 'cloture', 'gag law', 'blockage', 'law of closure', 'closing', 'settlement', 'resolution', 'occlusion', 'block', 'stop', 'closedown', 'shutdown', 'gag rule', 'closure', 'stoppage'}
# ['cases']
# [('cases', 'NNS')]
# {"compositor's case", 'vitrine', 'subject', 'eccentric', 'pillowcase', 'guinea pig', 'case', 'suit', 'causa', 'showcase', 'slip', 'shell', 'face', 'cause', 'character', 'fount', 'pillow slip', 'typeface', 'font', 'display case', 'cases', 'grammatical case', 'caseful', 'casing', 'lawsuit', 'type', "typesetter's case", 'instance', 'sheath', 'example', 'event'}
# ['testing', 'capacity']
# [('testing', 'VBG'), ('capacity', 'NN')]
# {'try out', 'quiz', 'screen', 'testing capacity', 'try', 'essay', 'examine', 'test', 'prove'}
# {'testing capacity'}
# ['deaths']
# [('deaths', 'NNS')]
# {'expiry', 'end', 'decease', 'death', 'dying', 'destruction', 'last', 'demise', 'deaths'}
# ['hospitalizations']
# [('hospitalizations', 'NNS')]
# {'hospitalisation', 'hospital care', 'hospitalization insurance', 'hospitalizations', 'hospitalization'}
# ['recoveries']
# [('recoveries', 'NNS')]
# {'recovery', 'recuperation', 'recoveries', 'retrieval', 'convalescence'}
# ['recovery', 'rate']
# [('recovery', 'NN'), ('rate', 'NN')]
# {'recovery', 'recuperation', 'retrieval', 'recovery rate', 'convalescence'}
# {'pace', 'recovery rate', 'rate', 'charge per unit'}
# ['positive', 'test', 'rate']
# [('positive', 'JJ'), ('test', 'NN'), ('rate', 'NN')]
# {'positively charged', 'electropositive', 'overconfident', 'positivist', 'prescribed', 'positive', 'confident', 'convinced', 'confirming', 'incontrovertible', 'irrefutable', 'cocksure', 'positive test rate', 'plus', 'positivistic'}
# {'positive test rate'}
# {'positive test rate'}
# ['icu', 'admissions']
# [('icu', 'NN'), ('admissions', 'NNS')]
# {'icu', 'intensive care unit', 'icu admissions'}
# {'admission fee', 'admittance', 'access', 'entrance fee', 'entrance money', 'accession', 'admission price', 'admission charge', 'price of admission', 'icu admissions', 'entree', 'admission'}
# ['ventilator', 'usage']
# [('ventilator', 'NN'), ('usage', 'NN')]
# {'ventilator', 'breathing apparatus', 'ventilator usage', 'breathing device', 'breathing machine'}
# {'use', 'ventilator usage', 'utilization', 'employment', 'usance', 'utilisation', 'exercise', 'usage', 'custom'}
# ['vaccinations', 'administered']
# [('vaccinations', 'NNS'), ('administered', 'VBD')]
# {'vaccination', 'inoculation', 'vaccinations administered'}
# {'vaccinations administered'}

# %%
syn_sets
# Out:
# {'MEDICAL-CONDITIONS': {'acuate',
#   'acute',
#   'acute kidney injury',
#   'acute respiratory distress syndrome',
#   'adult respiratory distress syndrome',
#   'ards',
#   'cardiovascular',
#   'cardiovascular complications',
#   'coagulopathy',
#   'cytokine',
#   'cytokine storm',
#   'discriminating',
#   'hypoxemia',
#   'incisive',
#   'intense',
#   'keen',
#   'knifelike',
#   'multi-organ failure',
#   'needlelike',
#   'penetrating',
#   'penetrative',
#   'piercing',
#   'pneumonia',
#   'respiratory',
#   'sepsis',
#   'sharp',
#   'storm',
#   'tempest',
#   'violent storm',
#   'wet lung',
#   'white lung'},
#  'SYMPTOMS': {'abruptness',
#   'ache',
#   'aching',
#   'appreciation',
#   'aroma',
#   'beaver state',
#   'body',
#   'body aches',
#   'breath',
#   'breather',
#   'breathing place',
#   'breathing space',
#   'breathing spell',
#   'breathing time',
#   'brusqueness',
#   'congestion',
#   'congestion or runny nose',
#   'consistence',
#   'consistency',
#   'cough',
#   'coughing',
#   'curtness',
#   'dead body',
#   'departure',
#   'deprivation',
#   'diarrhea',
#   'diarrhoea',
#   'discernment',
#   'disgorgement',
#   'emesis',
#   'eubstance',
#   'exit',
#   'expiration',
#   'fatigue',
#   'fatigue duty',
#   'febricity',
#   'febrility',
#   'feel',
#   'feeling',
#   'fever',
#   'feverishness',
#   'flavor',
#   'flavour',
#   'going',
#   'gruffness',
#   'gustation',
#   'gustatory modality',
#   'gustatory perception',
#   'gustatory sensation',
#   'hint',
#   'intimation',
#   'look',
#   'looseness',
#   'looseness of the bowels',
#   'loss',
#   'loss of taste or smell',
#   'mouthful',
#   'nausea',
#   'nausea or vomiting',
#   'nose',
#   'nozzle',
#   'odor',
#   'odour',
#   'olfaction',
#   'olfactory modality',
#   'olfactory organ',
#   'olfactory perception',
#   'olfactory property',
#   'olfactory sensation',
#   'operating room',
#   'operating theater',
#   'operating theatre',
#   'oregon',
#   'organic structure',
#   'over-crowding',
#   'passing',
#   'penchant',
#   'perceptiveness',
#   'personnel casualty',
#   'pharynx',
#   'physical structure',
#   'predilection',
#   'preference',
#   'puking',
#   'pyrexia',
#   'red',
#   'red ink',
#   'regurgitation',
#   'release',
#   'scent',
#   'sense of smell',
#   'sense of taste',
#   'shortness',
#   'shortness of breath',
#   'sickness',
#   'smell',
#   'smelling',
#   'sore',
#   'sore throat',
#   'soundbox',
#   'spirit',
#   'surgery',
#   'taste',
#   'taste perception',
#   'taste sensation',
#   'tasting',
#   'throat',
#   'tiredness',
#   'tone',
#   'torso',
#   'truncation',
#   'trunk',
#   'vomit',
#   'vomiting',
#   'weariness'},
#  'TREATMENTS': {'azithromycin',
#   'baricitinib',
#   'blood plasma',
#   'convalescent',
#   'convalescent plasma therapy',
#   'decadron',
#   'dexamethasone',
#   'dexamethasone intensol',
#   'dexone',
#   'favipiravir',
#   'hexadrol',
#   'ivermectin',
#   'monoclonal',
#   'monoclonal antibodies',
#   'oradexon',
#   'plasm',
#   'plasma',
#   'remdesivir',
#   'therapy',
#   'tocilizumab',
#   'vaccine',
#   'vaccinum',
#   'zithromax'},
#  'EVENTS': {'abode',
#   'adjoin',
#   'arrangement',
#   'authorisation',
#   'authorization',
#   'ball-shaped',
#   'base',
#   'body of work',
#   'campaign',
#   'cause',
#   'change of location',
#   'club',
#   'confinement',
#   'contact',
#   'crusade',
#   'decipher',
#   'declared',
#   'decree',
#   'delineate',
#   'describe',
#   'domicile',
#   'draw',
#   'drive',
#   'dwelling',
#   'dwelling house',
#   'economic',
#   'economic shutdowns initiated',
#   'economical',
#   'edict',
#   'effort',
#   'employment',
#   'essay',
#   'examine',
#   'family',
#   'fiat',
#   'follow',
#   'get hold of',
#   'get through',
#   'gild',
#   'global',
#   'global pandemic declared',
#   'globose',
#   'globular',
#   'guild',
#   'habitation',
#   'health care',
#   'healthcare',
#   'healthcare systems overwhelmed',
#   'holy order',
#   'home',
#   'home base',
#   'home plate',
#   'hound',
#   'house',
#   'household',
#   'hunt',
#   'hunting expedition',
#   'inoculation',
#   'limitation',
#   'line',
#   'locomotion',
#   'lodge',
#   'mandate',
#   'mandatory',
#   'mask',
#   'mask mandates enforced',
#   'masque',
#   'masquerade',
#   'masquerade party',
#   'meet',
#   'menage',
#   'military campaign',
#   'monastic order',
#   'movement',
#   'nursing home',
#   'oeuvre',
#   'orbicular',
#   'order',
#   'order of magnitude',
#   'ordering',
#   'orderliness',
#   'ordination',
#   'organisation',
#   'organization',
#   'pandemic',
#   'parliamentary law',
#   'parliamentary procedure',
#   'piece of work',
#   'place',
#   'planetary',
#   'plate',
#   'political campaign',
#   'prove',
#   'purchase order',
#   'quiz',
#   'rage',
#   'ramp',
#   'reach',
#   'rescript',
#   'rest home',
#   'restriction',
#   'retrace',
#   'rules of order',
#   'run',
#   'safari',
#   'scheme',
#   'school',
#   'school day',
#   'schoolhouse',
#   'schooling',
#   'schools closed',
#   'schooltime',
#   'screen',
#   'shoal',
#   'social',
#   'social club',
#   'social distancing guidelines introduced',
#   'societal',
#   'society',
#   'spheric',
#   'spherical',
#   'stated',
#   'storm',
#   'study',
#   'system',
#   'system of rules',
#   'test',
#   'testing and contact tracing ramped up',
#   'touch',
#   'trace',
#   'travel',
#   'travel restrictions implemented',
#   'traveling',
#   'travelling',
#   'try',
#   'try out',
#   'vaccination',
#   'vaccination campaigns rolled out',
#   'work',
#   'work from home orders issued',
#   'workplace',
#   'world',
#   'world-wide',
#   'worldwide'},
#  'POLICIES': {'assemblage',
#   'assembly',
#   'authorisation',
#   'authorization',
#   'bachelor of arts in nursing',
#   'ban',
#   'banning',
#   'batch',
#   'block',
#   'blockage',
#   'bound',
#   'boundary',
#   'bulk',
#   'business',
#   'business concern',
#   'business enterprise',
#   'business organisation',
#   'business organization',
#   'business sector',
#   'byplay',
#   'capability',
#   'capacitance',
#   'capacity',
#   'capacity limits for businesses',
#   'change of location',
#   'clientele',
#   'closedown',
#   'closing',
#   'closure',
#   'cloture',
#   'commercial enterprise',
#   'compulsory',
#   'concern',
#   'confinement',
#   'content',
#   'deal',
#   'demand',
#   'demarcation',
#   'demarcation line',
#   'distant',
#   'electrical capacity',
#   'essential',
#   'flock',
#   'forbiddance',
#   'forbidding',
#   'gag law',
#   'gag rule',
#   'gather',
#   'gathering',
#   'good deal',
#   'great deal',
#   'hatful',
#   'heap',
#   'hoi polloi',
#   'job',
#   'law of closure',
#   'limit',
#   'limit point',
#   'limitation',
#   'line',
#   'line of work',
#   'locomotion',
#   'lot',
#   'mandate',
#   'mandatory',
#   'mandatory testing for travelers',
#   'mask',
#   'mask mandate',
#   'masque',
#   'masquerade',
#   'masquerade party',
#   'mass',
#   'mass gathering bans',
#   'masses',
#   'mental ability',
#   'mess',
#   'mickle',
#   'mint',
#   'mountain',
#   'muckle',
#   'multitude',
#   'necessary',
#   'necessity',
#   'occlusion',
#   'occupation',
#   'outback',
#   'outside',
#   'passel',
#   'patronage',
#   'peck',
#   'people',
#   'pile',
#   'plenty',
#   'point of accumulation',
#   'pot',
#   'prerequisite',
#   'prohibition',
#   'proscription',
#   'quarantine',
#   'quarantine requirements',
#   'quite a little',
#   'raft',
#   'remote',
#   'remote work policies',
#   'removed',
#   'required',
#   'requirement',
#   'requisite',
#   'resolution',
#   'restriction',
#   'school',
#   'school closures',
#   'school day',
#   'schoolhouse',
#   'schooling',
#   'schooltime',
#   'settlement',
#   'shoal',
#   'shutdown',
#   'sight',
#   'slew',
#   'social',
#   'social distancing guidelines',
#   'societal',
#   'spate',
#   'stack',
#   'stage business',
#   'stay-at-home',
#   'stay-at-home orders',
#   'stop',
#   'stoppage',
#   'terminal point',
#   'terminus ad quem',
#   'the great unwashed',
#   'tidy sum',
#   'travel',
#   'travel restrictions',
#   'traveling',
#   'travelling',
#   'volume',
#   'wad'},
#  'METRICS': {'access',
#   'accession',
#   'admission',
#   'admission charge',
#   'admission fee',
#   'admission price',
#   'admittance',
#   'breathing apparatus',
#   'breathing device',
#   'breathing machine',
#   'case',
#   'caseful',
#   'cases',
#   'casing',
#   'causa',
#   'cause',
#   'character',
#   'charge per unit',
#   'cocksure',
#   "compositor's case",
#   'confident',
#   'confirming',
#   'convalescence',
#   'convinced',
#   'custom',
#   'death',
#   'deaths',
#   'decease',
#   'demise',
#   'destruction',
#   'display case',
#   'dying',
#   'eccentric',
#   'electropositive',
#   'employment',
#   'end',
#   'entrance fee',
#   'entrance money',
#   'entree',
#   'essay',
#   'event',
#   'examine',
#   'example',
#   'exercise',
#   'expiry',
#   'face',
#   'font',
#   'fount',
#   'grammatical case',
#   'guinea pig',
#   'hospital care',
#   'hospitalisation',
#   'hospitalization',
#   'hospitalization insurance',
#   'hospitalizations',
#   'icu',
#   'icu admissions',
#   'incontrovertible',
#   'inoculation',
#   'instance',
#   'intensive care unit',
#   'irrefutable',
#   'last',
#   'lawsuit',
#   'overconfident',
#   'pace',
#   'pillow slip',
#   'pillowcase',
#   'plus',
#   'positive',
#   'positive test rate',
#   'positively charged',
#   'positivist',
#   'positivistic',
#   'prescribed',
#   'price of admission',
#   'prove',
#   'quiz',
#   'rate',
#   'recoveries',
#   'recovery',
#   'recovery rate',
#   'recuperation',
#   'retrieval',
#   'screen',
#   'sheath',
#   'shell',
#   'showcase',
#   'slip',
#   'subject',
#   'suit',
#   'test',
#   'testing capacity',
#   'try',
#   'try out',
#   'type',
#   'typeface',
#   "typesetter's case",
#   'usage',
#   'usance',
#   'use',
#   'utilisation',
#   'utilization',
#   'vaccination',
#   'vaccinations administered',
#   'ventilator',
#   'ventilator usage',
#   'vitrine'}}

# %%
for label in res['label'].unique():
    print(len(syn_sets[label]))
    print(syn_sets[label])
# Out:
# 31
# {'wet lung', 'sepsis', 'adult respiratory distress syndrome', 'cytokine storm', 'cardiovascular complications', 'white lung', 'hypoxemia', 'acuate', 'cardiovascular', 'storm', 'intense', 'sharp', 'knifelike', 'keen', 'pneumonia', 'piercing', 'multi-organ failure', 'respiratory', 'incisive', 'violent storm', 'needlelike', 'discriminating', 'acute', 'cytokine', 'ards', 'acute respiratory distress syndrome', 'coagulopathy', 'penetrating', 'penetrative', 'tempest', 'acute kidney injury'}
# 115
# {'discernment', 'cough', 'curtness', 'weariness', 'consistence', 'tasting', 'brusqueness', 'personnel casualty', 'departure', 'operating room', 'body', 'odor', 'organic structure', 'mouthful', 'shortness of breath', 'gustatory sensation', 'fatigue duty', 'olfactory perception', 'emesis', 'appreciation', 'olfactory property', 'diarrhea', 'pyrexia', 'red ink', 'look', 'smell', 'feel', 'nose', 'gustatory modality', 'trunk', 'breathing spell', 'nozzle', 'tiredness', 'consistency', 'ache', 'deprivation', 'vomiting', 'vomit', 'truncation', 'regurgitation', 'taste perception', 'passing', 'feverishness', 'penchant', 'odour', 'looseness of the bowels', 'loss of taste or smell', 'congestion', 'taste', 'breathing space', 'spirit', 'oregon', 'sore throat', 'puking', 'sense of smell', 'body aches', 'aroma', 'flavor', 'breather', 'surgery', 'over-crowding', 'nausea', 'breathing time', 'throat', 'torso', 'abruptness', 'nausea or vomiting', 'perceptiveness', 'looseness', 'soundbox', 'breathing place', 'olfaction', 'gustatory perception', 'hint', 'olfactory sensation', 'intimation', 'loss', 'predilection', 'operating theater', 'flavour', 'physical structure', 'dead body', 'febrility', 'gruffness', 'sore', 'gustation', 'aching', 'operating theatre', 'fatigue', 'febricity', 'expiration', 'sense of taste', 'going', 'beaver state', 'diarrhoea', 'coughing', 'pharynx', 'fever', 'smelling', 'shortness', 'release', 'exit', 'feeling', 'red', 'olfactory organ', 'breath', 'sickness', 'tone', 'taste sensation', 'scent', 'olfactory modality', 'eubstance', 'disgorgement', 'congestion or runny nose', 'preference'}
# 23
# {'hexadrol', 'blood plasma', 'monoclonal antibodies', 'dexamethasone intensol', 'convalescent plasma therapy', 'decadron', 'vaccine', 'dexamethasone', 'therapy', 'zithromax', 'vaccinum', 'plasm', 'ivermectin', 'dexone', 'favipiravir', 'oradexon', 'remdesivir', 'convalescent', 'plasma', 'monoclonal', 'tocilizumab', 'azithromycin', 'baricitinib'}
# 144
# {'ordering', 'testing and contact tracing ramped up', 'work', 'rules of order', 'home base', 'house', 'stated', 'vaccination', 'delineate', 'holy order', 'social club', 'test', 'household', 'arrangement', 'home plate', 'order', 'schooling', 'worldwide', 'inoculation', 'drive', 'economic', 'run', 'get hold of', 'employment', 'decree', 'masquerade', 'parliamentary procedure', 'hound', 'edict', 'fiat', 'examine', 'lodge', 'political campaign', 'mandatory', 'authorization', 'economical', 'social distancing guidelines introduced', 'rage', 'globular', 'orderliness', 'global', 'limitation', 'masquerade party', 'school', 'shoal', 'retrace', 'meet', 'orbicular', 'schools closed', 'workplace', 'quiz', 'spherical', 'authorisation', 'schooltime', 'study', 'system', 'mask', 'family', 'scheme', 'school day', 'essay', 'order of magnitude', 'movement', 'economic shutdowns initiated', 'habitation', 'rescript', 'masque', 'trace', 'dwelling', 'body of work', 'home', 'dwelling house', 'declared', 'campaign', 'pandemic', 'work from home orders issued', 'confinement', 'ordination', 'touch', 'try', 'abode', 'travelling', 'purchase order', 'club', 'health care', 'guild', 'parliamentary law', 'mandate', 'ramp', 'travel', 'plate', 'storm', 'spheric', 'screen', 'adjoin', 'hunt', 'locomotion', 'change of location', 'globose', 'cause', 'mask mandates enforced', 'organisation', 'hunting expedition', 'decipher', 'nursing home', 'healthcare', 'safari', 'menage', 'effort', 'gild', 'describe', 'planetary', 'societal', 'base', 'place', 'schoolhouse', 'restriction', 'get through', 'follow', 'contact', 'social', 'monastic order', 'ball-shaped', 'traveling', 'try out', 'prove', 'global pandemic declared', 'world', 'military campaign', 'organization', 'vaccination campaigns rolled out', 'draw', 'system of rules', 'line', 'world-wide', 'crusade', 'healthcare systems overwhelmed', 'oeuvre', 'society', 'rest home', 'piece of work', 'travel restrictions implemented', 'reach', 'domicile'}
# 141
# {'people', 'mickle', 'bound', 'byplay', 'mask mandate', 'prerequisite', 'stack', 'limit point', 'resolution', 'mandatory testing for travelers', 'removed', 'capacitance', 'gag rule', 'bachelor of arts in nursing', 'stage business', 'schooling', 'stoppage', 'peck', 'spate', 'stay-at-home', 'cloture', 'mass', 'hatful', 'settlement', 'gathering', 'great deal', 'necessity', 'job', 'masquerade', 'outback', 'pot', 'social distancing guidelines', 'business concern', 'business', 'masses', 'gather', 'mass gathering bans', 'mandatory', 'authorization', 'pile', 'lot', 'closing', 'masquerade party', 'limitation', 'school', 'shoal', 'travel restrictions', 'sight', 'block', 'remote', 'banning', 'terminal point', 'point of accumulation', 'clientele', 'remote work policies', 'stay-at-home orders', 'gag law', 'authorisation', 'schooltime', 'essential', 'outside', 'mask', 'prohibition', 'school day', 'demarcation', 'business enterprise', 'slew', 'demarcation line', 'plenty', 'mint', 'masque', 'necessary', 'mental ability', 'proscription', 'concern', 'boundary', 'confinement', 'line of work', 'occlusion', 'bulk', 'good deal', 'travelling', 'raft', 'business organization', 'mandate', 'wad', 'closure', 'school closures', 'travel', 'demand', 'ban', 'blockage', 'quite a little', 'volume', 'requisite', 'patronage', 'heap', 'batch', 'content', 'locomotion', 'electrical capacity', 'change of location', 'capability', 'stop', 'required', 'closedown', 'business sector', 'mess', 'forbiddance', 'societal', 'flock', 'capacity limits for businesses', 'compulsory', 'mountain', 'schoolhouse', 'restriction', 'deal', 'shutdown', 'quarantine', 'passel', 'social', 'distant', 'assemblage', 'traveling', 'business organisation', 'law of closure', 'capacity', 'commercial enterprise', 'the great unwashed', 'line', 'hoi polloi', 'muckle', 'forbidding', 'occupation', 'multitude', 'requirement', 'tidy sum', 'quarantine requirements', 'terminus ad quem', 'limit', 'assembly'}
# 108
# {'expiry', 'electropositive', 'vitrine', 'subject', 'eccentric', 'decease', 'guinea pig', 'entrance money', 'accession', 'admission price', 'utilisation', 'vaccination', 'test', 'case', 'admission', 'deaths', 'breathing apparatus', 'causa', 'inoculation', 'pace', 'overconfident', 'positivist', 'prescribed', 'employment', 'slip', 'confirming', 'face', 'character', 'incontrovertible', 'examine', 'usage', 'positivistic', 'hospitalisation', 'pillow slip', 'font', 'display case', 'entrance fee', 'utilization', 'confident', 'death', 'retrieval', 'cocksure', 'caseful', 'casing', 'quiz', 'ventilator', 'ventilator usage', 'type', 'instance', 'irrefutable', 'essay', 'positive test rate', 'sheath', 'price of admission', 'demise', 'hospitalization', 'plus', 'positively charged', "compositor's case", 'pillowcase', 'try', 'admission charge', 'exercise', 'suit', 'end', 'recovery', 'use', 'admittance', 'vaccinations administered', 'screen', 'showcase', 'hospitalizations', 'icu', 'positive', 'shell', 'recovery rate', 'cause', 'destruction', 'icu admissions', 'fount', 'typeface', 'cases', 'hospital care', 'access', 'testing capacity', 'recuperation', 'grammatical case', 'dying', 'rate', 'intensive care unit', 'breathing machine', 'custom', 'lawsuit', 'entree', 'prove', 'try out', 'admission fee', 'charge per unit', 'breathing device', 'hospitalization insurance', "typesetter's case", 'convinced', 'recoveries', 'usance', 'last', 'example', 'event', 'convalescence'}

# %%
pd.DataFrame.from_dict(data=syn_sets, orient='index').to_csv('all_relevant.csv', header=False)
